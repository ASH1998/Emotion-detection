# %%
from keras.models import load_model
from sklearn.metrics import confusion_matrix
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display, Image

import pandas as pd
import numpy as np

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# !pwd
# Out:
# /home/ashu2_gamer/Project/FER2013-or/Emotion-detection

# %%
model = load_model('/home/ashu2_gamer/Project/FER2013-or/fer2013prep1.h5')

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv2D at 0x7fbb3fa436a0>,
#  <keras.layers.convolutional.Conv2D at 0x7fbb3fa43ba8>,
#  <keras.layers.convolutional.Conv2D at 0x7fbb3fa5fdd8>,
#  <keras.layers.core.Dropout at 0x7fbbe08b0d30>,
#  <keras.layers.pooling.MaxPooling2D at 0x7fbb3fa43a20>,
#  <keras.layers.convolutional.Conv2D at 0x7fbbe08c9a90>,
#  <keras.layers.convolutional.Conv2D at 0x7fbbe0882780>,
#  <keras.layers.core.Dropout at 0x7fbbe08a6be0>,
#  <keras.layers.convolutional.Conv2D at 0x7fbbe08b0cf8>,
#  <keras.layers.pooling.MaxPooling2D at 0x7fbbe0858438>,
#  <keras.layers.local.LocallyConnected2D at 0x7fbbe083f8d0>,
#  <keras.layers.local.LocallyConnected2D at 0x7fbbe05f2860>,
#  <keras.layers.core.Flatten at 0x7fbbe014d630>,
#  <keras.layers.core.Dense at 0x7fbbe014d860>,
#  <keras.layers.core.Dropout at 0x7fbb5da60e10>,
#  <keras.layers.core.Dense at 0x7fbb5d9fe358>,
#  <keras.layers.core.Dense at 0x7fbbe0858710>]

# %%
#!sudo wget http://www.randymoraitis.com/wp-content/uploads/2018/01/angryface.jpg --no-check-certificate
# Out:
# --2018-10-03 04:25:36--  http://www.randymoraitis.com/wp-content/uploads/2018/01/angryface.jpg
# Resolving www.randymoraitis.com (www.randymoraitis.com)... 50.62.114.1
# Connecting to www.randymoraitis.com (www.randymoraitis.com)|50.62.114.1|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103314 (101K) [image/jpeg]
# Saving to: ‘angryface.jpg’
#
# angryface.jpg       100%[===================>] 100.89K  --.-KB/s    in 0.1s
#
# 2018-10-03 04:25:37 (797 KB/s) - ‘angryface.jpg’ saved [103314/103314]

# %%
def get_emotion(ohv):
    if ohv.shape[0] == 1:
        indx = ohv[0]
    else:
        indx = np.argmax(ohv)
        
    if indx == 0:
        return 'angry'
    elif indx == 1:
        return 'disgust'
    elif indx == 2:
        return 'fear'
    elif indx == 3:
        return 'happy'
    elif indx == 4:
        return 'sad'
    elif indx == 5:
        return 'surprise'
    elif indx == 6:
        return 'neutral'

# %%
img_path = 'happy-boy-face-10.jpg'
img = image.load_img(img_path, color_mode='grayscale',target_size=(48, 48))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

# %%
preds = model.predict(x)

# %%
pred_cls = model.predict_classes(x)
display(Image(img_path))
print('> predicted emotion: %s' % (get_emotion(pred_cls)))
# Out:
# > predicted emotion: happy

# %%
X = np.load('img_test.npy')
y = np.load('lbl_test.npy')

# %%
def predict(mdl, img):
  emotions = ['Anger', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
  im = np.zeros((1, 48, 48, 1))
  im[0] = img
  p = mdl.predict(im)

  i = np.argmax(p)
  
  plt.imshow(np.reshape(img, (48,48)), cmap='gray')
  plt.title('Test Image (Predicted Label: ' + emotions[i] + ')')
  return p

# %%
predict(model, X[262])
# Out:
# array([[8.4743435e-03, 6.0161838e-08, 3.7563252e-03, 9.8136628e-01,
#         1.5128077e-03, 2.0485481e-03, 2.8416032e-03]], dtype=float32)

# %%
img_indx = 1607
sample = X[img_indx, :]
sample = sample.reshape(48, 48)

pred_cls = model.predict_classes(sample.reshape(1, 48, 48, 1))

plt.imshow(sample, cmap='gray')
plt.show()
print('> testing image index: %d\n> true emotion: %s\n> predicted emotion: %s' % (img_indx, get_emotion(y[img_indx, :]), get_emotion(pred_cls)))
# Out:
# > testing image index: 1607
# > true emotion: sad
# > predicted emotion: sad

# %%
y_prob = model.predict(X, batch_size=32, verbose=0)
y_pred = [np.argmax(prob) for prob in y_prob]
y_true = [np.argmax(true) for true in y]
labels = ['Anger', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# %%
def plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure(figsize=(6,6))
    matplotlib.rcParams.update({'font.size': 16})
    ax  = fig.add_subplot(111)
    matrix = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    fig.colorbar(matrix) 
    for i in range(0,7):
        for j in range(0,7):  
            ax.text(j,i,cm[i,j],va='center', ha='center')
    # ax.set_title('Confusion Matrix')
    ticks = np.arange(len(labels))
    ax.set_xticks(ticks)
    ax.set_xticklabels(labels, rotation=45)
    ax.set_yticks(ticks)
    ax.set_yticklabels(labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.YlGnBu)
plt.show()

# %%
confusion_matrix(y_pred, y_true)
# Out:
# array([[221,  34,  74,  30,  85,  20,  58],
#        [  0,   1,   0,   0,   0,   0,   0],
#        [ 43,   5, 138,  21,  42,  40,  24],
#        [ 46,   3,  61, 708,  77,  29,  75],
#        [ 82,  10, 119,  49, 230,  16,  96],
#        [ 17,   0,  50,  15,  13, 264,  17],
#        [ 82,   2,  86,  56, 147,  47, 356]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=labels))
# Out:
#              precision    recall  f1-score   support
#
#       Anger       0.42      0.45      0.44       491
#     Disgust       1.00      0.02      0.04        55
#        Fear       0.44      0.26      0.33       528
#       Happy       0.71      0.81      0.75       879
#         Sad       0.38      0.39      0.38       594
#    Surprise       0.70      0.63      0.67       416
#     Neutral       0.46      0.57      0.51       626
#
# avg / total       0.54      0.53      0.52      3589

# %%
def class_precision(y_true, y_pred, emotion):
    cm = confusion_matrix(y_true, y_pred)
    i = [i for i, label in enumerate(labels) if label == emotion][0]
    col = [cm[j,i] for j in range(0,7)]
    return float(col[i])/sum(col)

def class_recall(y_true, y_pred, emotion):
    cm = confusion_matrix(y_true, y_pred)
    i = [i for i, label in enumerate(labels) if label == emotion][0]
    row = [cm[i,j] for j in range(0,6)]
    return float(row[i])/sum(row)

def class_accuracy(y_true, y_pred, emotion):
    cm = confusion_matrix(y_true, y_pred)
    i = [i for i, label in enumerate(labels) if label == emotion][0]
    tp = cm[i,i]
    fn = sum([cm[i,j] for j in range(0,7) if j != i])
    fp = sum([cm[j,i] for j in range(0,7) if j != i])
    tn = sum([cm[i,j] for j in range(0,7) for i in range(0,7)]) -(tp+fp+fn)
    return float(tp + tn)/sum([tp, fn, fp, tn])

# %%
for emotion in labels:
    print(emotion.upper())
    print('   acc = {}'.format(class_accuracy(y_true, y_pred, emotion)))
    print('  prec = {}'.format(class_precision(y_true, y_pred, emotion)))
    print('recall = {}\n'.format(class_recall(y_true, y_pred, emotion)))
# Out:
# ANGER
#    acc = 0.8409027584285316
#   prec = 0.42337164750957856
# recall = 0.5403422982885085
#
# DISGUST
#    acc = 0.9849540261911396
#   prec = 1.0
# recall = 0.018867924528301886
#
# FEAR
#    acc = 0.8425745332961828
#   prec = 0.44089456869009586
# recall = 0.31221719457013575
#
# HAPPY
#    acc = 0.8712733351908609
#   prec = 0.7087087087087087
# recall = 0.8602673147023087
#
# SAD
#    acc = 0.7949289495681249
#   prec = 0.38205980066445183
# recall = 0.5145413870246085
#
# SURPRISE
#    acc = 0.9264419058233492
#   prec = 0.7021276595744681
# recall = 0.7154471544715447
#
# NEUTRAL
#    acc = 0.807745890220117
#   prec = 0.4587628865979381
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-2a731fa9e7a0> in <module>
#       3     print('   acc = {}'.format(class_accuracy(y_true, y_pred, emotion)))
#       4     print('  prec = {}'.format(class_precision(y_true, y_pred, emotion)))
# ----> 5     print('recall = {}\n'.format(class_recall(y_true, y_pred, emotion)))
#
# <ipython-input-30-5689f1820b7b> in class_recall(y_true, y_pred, emotion)
#       9     i = [i for i, label in enumerate(labels) if label == emotion][0]
#      10     row = [cm[i,j] for j in range(0,6)]
# ---> 11     return float(row[i])/sum(row)
#      12
#      13 def class_accuracy(y_true, y_pred, emotion):
#
# IndexError: list index out of range
